# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Yash\Desktop\amazon.csv")

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   object
#  1   product_name         1465 non-null   object
#  2   category             1465 non-null   object
#  3   discounted_price     1465 non-null   object
#  4   actual_price         1465 non-null   object
#  5   discount_percentage  1465 non-null   object
#  6   rating               1465 non-null   object
#  7   rating_count         1463 non-null   object
#  8   about_product        1465 non-null   object
#  9   user_id              1465 non-null   object
#  10  user_name            1465 non-null   object
#  11  review_id            1465 non-null   object
#  12  review_title         1465 non-null   object
#  13  review_content       1465 non-null   object
#  14  img_link             1465 non-null   object
# ...

# %%
df.shape
# Out:
# (1465, 16)

# %%
(df["rating_count"].isna().sum()/df.shape[0])*100
# Out:
# 0.13651877133105803

# %%
df=df.dropna()

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
df['category']
# Out:
# 0       Computers&Accessories|Accessories&Peripherals|...
# 1       Computers&Accessories|Accessories&Peripherals|...
# 2       Computers&Accessories|Accessories&Peripherals|...
# 3       Computers&Accessories|Accessories&Peripherals|...
# 4       Computers&Accessories|Accessories&Peripherals|...
#                               ...
# 1460    Home&Kitchen|Kitchen&HomeAppliances|WaterPurif...
# 1461    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# 1462    Home&Kitchen|Heating,Cooling&AirQuality|RoomHe...
# 1463    Home&Kitchen|Heating,Cooling&AirQuality|Fans|E...
# 1464    Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...
# Name: category, Length: 1463, dtype: object

# %%
df['category'].loc[0]
# Out:
# 'Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'

# %%
a='Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables'
a=a.split("|")
print(a[0])
# Out:
# Computers&Accessories

# %%
a=[]

for i in df["category"]:
    i=i.split("|")
    a.append(i[0])

# %%
df["category"]=a
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_11012\558900275.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["category"]=a

# %%
df["category"]
# Out:
# 0       Computers&Accessories
# 1       Computers&Accessories
# 2       Computers&Accessories
# 3       Computers&Accessories
# 4       Computers&Accessories
#                 ...
# 1460             Home&Kitchen
# 1461             Home&Kitchen
# 1462             Home&Kitchen
# 1463             Home&Kitchen
# 1464             Home&Kitchen
# Name: category, Length: 1463, dtype: object

# %%
df.dtypes
# Out:
# product_id             object
# product_name           object
# category               object
# discounted_price       object
# actual_price           object
# discount_percentage    object
# rating                 object
# rating_count           object
# about_product          object
# user_id                object
# user_name              object
# review_id              object
# review_title           object
# review_content         object
# img_link               object
# product_link           object
# dtype: object

# %%
def change(x):
    x=x.replace("₹","")
    x=x.replace(",","")
    return x

# %%
df["discounted_price"]=df["discounted_price"].apply(lambda a:change(a))
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_11012\297762830.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["discounted_price"]=df["discounted_price"].apply(lambda a:change(a))

# %%
df["discounted_price"]=df["discounted_price"].astype("float")
# Out:
# C:\Users\Yash\AppData\Local\Temp\ipykernel_11012\3880128061.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["discounted_price"]=df["discounted_price"].astype("float")

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='object')

# %%
def change(x):
    x=x.replace("₹","")
    x=x.replace(",","")
    x=x.replace("%","")
    return x

# %%
df['actual_price']=df['actual_price'].apply(lambda a:change(a))

# %%
df['actual_price']=df['actual_price'].astype("float")

# %%
df['discount_percentage']=df['discount_percentage'].apply(lambda a: change(a))

# %%
df['discount_percentage']=df['discount_percentage'].astype('int')

# %%
df[df['rating']=="|"]
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
#
#           category  discounted_price  actual_price  discount_percentage  \
# 1279  Home&Kitchen            2099.0        2499.0                   16
#
#      rating rating_count                                      about_product  \
# 1279      |          992  No Installation is provided for this product|1...
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
#
# ...

# %%
df['rating']=df['rating'].replace("|",np.nan)

# %%
df
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories             399.0        1099.0
# ...

# %%
df=df.dropna()

# %%
df['rating']=df['rating'].astype("float")

# %%
df_new=df[['category', 'discounted_price','actual_price', 'discount_percentage', 'rating', 'rating_count']]

# %%
df_new['rating_count']=df_new['rating_count'].apply(lambda a:change(a))

# %%
df_new
# Out:
#                    category  discounted_price  actual_price  \
# 0     Computers&Accessories             399.0        1099.0
# 1     Computers&Accessories             199.0         349.0
# 2     Computers&Accessories             199.0        1899.0
# 3     Computers&Accessories             329.0         699.0
# 4     Computers&Accessories             154.0         399.0
# ...                     ...               ...           ...
# 1460           Home&Kitchen             379.0         919.0
# 1461           Home&Kitchen            2280.0        3045.0
# 1462           Home&Kitchen            2219.0        3080.0
# 1463           Home&Kitchen            1399.0        1890.0
# 1464           Home&Kitchen            2863.0        3690.0
#
#       discount_percentage  rating rating_count
# 0                      64     4.2        24269
# 1                      43     4.0        43994
# 2                      90     3.9         7928
# 3                      53     4.2        94363
# ...

# %%
df_cat_vs_dp=df.groupby(['category'],as_index=False)['discounted_price'].sum().sort_values(by="discounted_price",ascending=False).head(3)

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.barplot(x="category",y="discounted_price",data=df_cat_vs_dp)
plt.show()
